# %%
import glob

# %%
# Out:
# /home/chronotope/workspace/robusttail

# %%
import shutil

# %%
for file_name in glob.glob("./testResultSmall/*"):
    shutil.move(file_name, dest1)

# %%
[file_name.replace("00000000000001","").replace("0000000000001","") ]
# Out:
# ['./testResultSmall/tailProbabilityEstimation_dataDistribution=lognorm_dataSize=800_percentageLHS=0.91_percentageRHS=0.915_thresholdPercentage=0.625_alpha=0.05_gEllipsoidalDimension=3_randomSeed=20220222_nExperimentReptition=10.csv',
#  './testResultSmall/quantileEstimation_dataDistribution=gamma_dataSize=800_quantitleValue=0.9_thresholdPercentage=0.675_alpha=0.05_gEllipsoidalDimension=3_randomSeed=20220222_nExperimentReptition=10.csv',
#  './testResultSmall/quantileEstimation_dataDistribution=gamma_dataSize=500_quantitleValue=0.98_thresholdPercentage=0.675_alpha=0.05_gEllipsoidalDimension=3_randomSeed=20220222_nExperimentReptition=10.csv',
#  './testResultSmall/tailProbabilityEstimation_dataDistribution=lognorm_dataSize=500_percentageLHS=0.91_percentageRHS=0.915_thresholdPercentage=0.725_alpha=0.05_gEllipsoidalDimension=3_randomSeed=20220222_nExperimentReptition=10.csv',
# ...

# %%
import numpy as np

# %%
np.min(each for each in range(5))
# Out:
# <generator object <genexpr> at 0x7fcbcd21beb0>

# %%
os.path.isdir("testResult1")
# Out:
# False

# %%
print(df.mean(axis=0).values)
# Out:
# [0.04258389 0.02399528 0.01470568 0.06816522 0.02411434 0.01327628]

# %%
from multiprocessing import Pool
import tailProbabilityEstimation as tailP
from scipy.stats import gamma, lognorm, pareto, genpareto
import pandas as pd
import numpy as np
import os
import itertools
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a47fc1ccd9fe> in <module>
#       1 from multiprocessing import Pool
# ----> 2 import tailProbabilityEstimation as tailP
#       3 from scipy.stats import gamma, lognorm, pareto, genpareto
#       4 import pandas as pd
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'tailProbabilityEstimation'

# %%
metaDataDict = {"dataSize": 800,
                "percentageLHS": 0.6,
                "percentageRHS": 0.999,
                "thresholdPercentage": 0.7,
                "alpha": 0.05,
                "gEllipsoidalDimension": 3}

# %%
dataDistribution=gamma_dataSize=500_percentageLHS=0.9450000000000001_percentageRHS=0.9950000000000001_thresholdPercentage=0.85_alpha=0.05_gEllipsoidalDimension=3_randomSeed=20220222_nExperimentReptition=500

# %%
np.linspace(0.9, 0.99, 10)
# Out:
# array([0.9 , 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99])

# %%
np.linspace(0.6, 0.85, 11)
# Out:
# array([0.6  , 0.625, 0.65 , 0.675, 0.7  , 0.725, 0.75 , 0.775, 0.8  ,
#        0.825, 0.85 ])

# %%
0.95625+0.005
# Out:
# 0.96125

# %%
import numpy as np

# %%
np.linspace(0.9, 0.99, 9)
# Out:
# array([0.9    , 0.91125, 0.9225 , 0.93375, 0.945  , 0.95625, 0.9675 ,
#        0.97875, 0.99   ])

# %%
metaDataDict={"dataSize":500,
              "percentageLHS":0.99,
              "percentageRHS":0.99999999,
              "thresholdPercentage":0.7,
              "alpha":0.05,
              "gEllipsoidalDimension":3}
nExperimentReptition = 500

# %%
FILE_NAME
# Out:
# 'dataSize=500_percentageLHS=0.99_percentageRHS=0.99999999_thresholdPercentage=0.7_alpha=0.05_gEllipsoidalDimension=3_nExperimentReptition=500.csv'

# %%
os.path.join("1","2")
# Out:
# '1/2'

# %%
import numpy as np

# %%
np.linspace(0.6,0.85,26)
# Out:
# array([0.6 , 0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.7 ,
#        0.71, 0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.8 , 0.81,
#        0.82, 0.83, 0.84, 0.85])

# %%
0.005+0.95
# Out:
# 0.955

# %%
gamma
8

# %%
np.linspace(0.9, 0.99, 9)
# Out:
# array([0.9    , 0.91125, 0.9225 , 0.93375, 0.945  , 0.95625, 0.9675 ,
#        0.97875, 0.99   ])

# %%
0.99+0.005+0.005
# Out:
# 1.0

# %%
thresholdPercentages = np.linspace(0.6, 0.85, 13)
percentageLHSs = np.linspace(0.9, 0.99, 9)
dataSizes = [500, 800, 1000, 1200, 1500, 1800, 2000, 2500, 3000]
list(itertools.product()
# Out:
# [(0.6, 0.9, 500),
#  (0.6, 0.9, 800),
#  (0.6, 0.9, 1000),
#  (0.6, 0.9, 1200),
#  (0.6, 0.9, 1500),
#  (0.6, 0.9, 1800),
#  (0.6, 0.9, 2000),
#  (0.6, 0.9, 2500),
#  (0.6, 0.9, 3000),
#  (0.6, 0.91125, 500),
#  (0.6, 0.91125, 800),
#  (0.6, 0.91125, 1000),
#  (0.6, 0.91125, 1200),
#  (0.6, 0.91125, 1500),
#  (0.6, 0.91125, 1800),
#  (0.6, 0.91125, 2000),
#  (0.6, 0.91125, 2500),
#  (0.6, 0.91125, 3000),
#  (0.6, 0.9225, 500),
#  (0.6, 0.9225, 800),
#  (0.6, 0.9225, 1000),
#  (0.6, 0.9225, 1200),
#  (0.6, 0.9225, 1500),
#  (0.6, 0.9225, 1800),
#  (0.6, 0.9225, 2000),
#  (0.6, 0.9225, 2500),
#  (0.6, 0.9225, 3000),
#  (0.6, 0.93375, 500),
#  (0.6, 0.93375, 800),
#  (0.6, 0.93375, 1000),
#  (0.6, 0.93375, 1200),
#  (0.6, 0.93375, 1500),
#  (0.6, 0.93375, 1800),
#  (0.6, 0.93375, 2000),
#  (0.6, 0.93375, 2500),
#  (0.6, 0.93375, 3000),
#  (0.6, 0.9450000000000001, 500),
#  (0.6, 0.9450000000000001, 800),
#  (0.6, 0.9450000000000001, 1000),
#  (0.6, 0.9450000000000001, 1200),
# ...
